# %% [markdown]
# # Imports

# %%
import xarray as xr

# %%
path = '/glade/campaign/cgd/ccr/E3SMv2/FV_regridded/v2.FV1.historical_0101/atm/proc/tseries/month_1/'
temps = xr.open_dataset(path+'v2.FV1.historical_0101.eam.h0.T.185001-201412.nc')
# surface temp is radiative
# surface_temp = xr.open_dataset(path+'v2.FV1.historical_0101.eam.h0.TS.185001-201412.nc')

# %%
temps.lev
# Out:
# <xarray.DataArray 'lev' (lev: 72)> Size: 576B
# array([1.238254e-01, 1.828292e-01, 2.699489e-01, 3.985817e-01, 5.885091e-01,
#        8.689386e-01, 1.282995e+00, 1.894352e+00, 2.797027e+00, 4.129833e+00,
#        5.968449e+00, 8.377404e+00, 1.147379e+01, 1.533394e+01, 1.999634e+01,
#        2.544470e+01, 3.159325e+01, 3.836628e+01, 4.567120e+01, 5.330956e+01,
#        6.101518e+01, 6.847639e+01, 7.535534e+01, 8.194628e+01, 8.891054e+01,
#        9.646667e+01, 1.046650e+02, 1.135600e+02, 1.232110e+02, 1.336822e+02,
#        1.450433e+02, 1.573699e+02, 1.707441e+02, 1.852549e+02, 2.009989e+02,
#        2.180810e+02, 2.366148e+02, 2.567237e+02, 2.785416e+02, 3.022136e+02,
#        3.278975e+02, 3.557641e+02, 3.859990e+02, 4.188035e+02, 4.543958e+02,
#        4.924686e+02, 5.316395e+02, 5.706249e+02, 6.086438e+02, 6.453200e+02,
#        6.804980e+02, 7.137046e+02, 7.444748e+02, 7.723628e+02, 7.969527e+02,
#        8.178688e+02, 8.350952e+02, 8.496612e+02, 8.631764e+02, 8.763706e+02,
# ...

# %%
temps.sel(time='2000-01-01')['T'].plot()
# Out:
# (array([ 80361., 232069., 648420., 596760., 387282., 544768., 526439.,
#         509858., 355504.,  99851.]),
#  array([181.26727295, 193.80841064, 206.34954834, 218.89070129,
#         231.43183899, 243.97297668, 256.51412964, 269.05526733,
#         281.59640503, 294.13754272, 306.67868042]),
#  <BarContainer object of 10 artists>)

# %%
var = 'OCNFRAC'
ts = xr.open_dataset(path+ 'v2.FV1.historical_0101.eam.h0.'+var+ '.185001-201412.nc')
ts[var].long_name
# Out:
# 'Fraction of sfc area covered by ocean'

# %%
path2 = '/glade/campaign/cgd/ccr/E3SMv2/FV_regridded/v2.FV1.historical_0101/atm/proc/tseries/day_1/'
var = 'TOZ'
file = path2 + 'v2.FV1.historical_0101.eam.h1.' + var + '.18500101-20141231.nc'
test = xr.open_dataset(file)
test
# Out:
# <xarray.Dataset> Size: 13GB
# Dimensions:              (lat: 192, lon: 288, nbnd: 2, cosp_ht: 40,
#                           cosp_htmisr: 16, cosp_prs: 7, cosp_reffice: 6,
#                           cosp_reffliq: 6, cosp_scol: 10, cosp_sr: 15,
#                           cosp_sza: 5, cosp_tau: 7, cosp_tau_modis: 7,
#                           ilev: 73, lev: 72, time: 60226)
# Coordinates: (12/15)
#   * lat                  (lat) float64 2kB -90.0 -89.06 -88.12 ... 89.06 90.0
#   * lon                  (lon) float64 2kB 0.0 1.25 2.5 ... 356.2 357.5 358.8
#   * cosp_ht              (cosp_ht) float64 320B 1.896e+04 1.848e+04 ... 240.0
#   * cosp_htmisr          (cosp_htmisr) float64 128B 0.0 250.0 ... 1.8e+04
#   * cosp_prs             (cosp_prs) float64 56B 9e+04 7.4e+04 ... 2.45e+04 9e+03
#   * cosp_reffice         (cosp_reffice) float64 48B 5e-06 1.5e-05 ... 7.5e-05
#     ...                   ...
#   * cosp_sza             (cosp_sza) float64 40B 0.0 20.0 40.0 60.0 80.0
# ...
