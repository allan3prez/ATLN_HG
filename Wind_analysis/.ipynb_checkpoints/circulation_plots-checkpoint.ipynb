# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# # Plot function

# %%
def plot_circulation(uds, wds, scale=500, con_bg=True, index='', map_ref=True, season='', source=''):
    fig = plt.figure(figsize=(16, 8))
    gs = fig.add_gridspec(2, 1, height_ratios=[2, 1], hspace=-0.52)
    
    lons = uds['lon'].values
    levs = uds['level'].values
    # scale vertical pressure change by normalized pressure for visual correction
    _, P_grid = np.meshgrid(lons, levs)
    P_ref = levs.max()
    pressure_scale = P_ref / P_grid
    vds = wds * pressure_scale * scale
    
    # skip every other arrow
    skip = {'lon': slice(None, None, 10), 'level': slice(None, None, 1)}
    X_sparse = uds['lon'].isel({'lon': slice(None, None, 10)})
    Y_sparse = uds['level'].isel({'level': slice(None, None, 1)})
    U_sparse = uds.isel(skip)
    V_sparse = vds.isel(skip)


    ax = fig.add_subplot(gs[0], zorder=2)
    ax.set_facecolor('none')
    if con_bg:
        con_levels = np.arange(-0.005, 0.006, 0.0005)
        con = ax.contourf(lons, levs, wds.values, levels=con_levels, cmap='RdBu_r', extend='both', alpha=0.7)
        cbar = plt.colorbar(con, ax=ax, label=f'Vertical Velocity (Pa/s)')
        
    Q = ax.quiver(X_sparse, Y_sparse, U_sparse, V_sparse, angles='xy')
    ax.set_xticklabels([])
    ax.set_xlim(lons.min(), lons.max())
    ax.invert_yaxis()
    ax.set_aspect(0.08)
    ax.set_ylabel('Pressure Level (hPa)')
    ax.grid(True, linestyle='--', alpha=0.5)

    plt.title(f'Significant Mean Zonal Wind Anomalies During {season} Related to {index} from {source}')
    # map reference in bottom axis
    if map_ref:
        map_ax = fig.add_subplot(gs[1], projection=ccrs.PlateCarree(), zorder=1, alpha=0.2)
        map_ax.add_feature(cfeature.COASTLINE, alpha=0.2)
        map_ax.add_feature(cfeature.LAND, alpha=0.2)
        map_ax.plot([lons.min(), lons.max()], [0, 0], color='red', linewidth=2, transform=ccrs.PlateCarree())
        map_ax.set_extent([lons.min(), lons.max(), -20, 20], crs=ccrs.PlateCarree())
        map_ax.set_aspect(0.4)
        map_ax.set_xlabel('Longitude (degrees)')
        pos_ax = ax.get_position()
        pos_map_ax = map_ax.get_position()
        new_map_ax_pos = [pos_ax.x0, pos_map_ax.y0, pos_ax.width, pos_map_ax.height]
        map_ax.set_position(new_map_ax_pos)
        gl = map_ax.gridlines(draw_labels=True, linestyle='--', alpha=0.5)
        gl.top_labels = False
        gl.right_labels = False
        gl.left_labels = False
    plt.show()

# %% [markdown]
# # Reanalysis

# %%
RA_reg_ds = xr.open_dataset('/glade/work/acruz/Reanalysis/wind_regression.nc', engine='h5netcdf')
RA_reg_ds
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:            (level: 37, lon: 801)
# Coordinates:
#   * level              (level) float64 296B 1.0 2.0 3.0 ... 950.0 975.0 1e+03
#   * lon                (lon) float64 6kB -180.0 -179.8 -179.5 ... 19.75 20.0
# Data variables: (12/16)
#     JJA_U_EANI_slope   (level, lon) float32 119kB ...
#     JJA_U_EANI_pvalue  (level, lon) float32 119kB ...
#     JJA_W_EANI_slope   (level, lon) float32 119kB ...
#     JJA_W_EANI_pvalue  (level, lon) float32 119kB ...
#     JJA_U_CANI_slope   (level, lon) float32 119kB ...
#     JJA_U_CANI_pvalue  (level, lon) float32 119kB ...
#     ...                 ...
#     SON_W_EANI_slope   (level, lon) float32 119kB ...
#     SON_W_EANI_pvalue  (level, lon) float32 119kB ...
#     SON_U_CANI_slope   (level, lon) float32 119kB ...
#     SON_U_CANI_pvalue  (level, lon) float32 119kB ...
#     SON_W_CANI_slope   (level, lon) float32 119kB ...
#     SON_W_CANI_pvalue  (level, lon) float32 119kB ...
# Attributes:
# ...

# %%
# mask by pvalue threshold
pvt = 0.05

JJA_U_EANI_sig = RA_reg_ds['JJA_U_EANI_slope'].where(RA_reg_ds['JJA_U_EANI_pvalue'] <= pvt)
JJA_W_EANI_sig = RA_reg_ds['JJA_W_EANI_slope'].where(RA_reg_ds['JJA_W_EANI_pvalue'] <= pvt)
JJA_U_CANI_sig = RA_reg_ds['JJA_U_CANI_slope'].where(RA_reg_ds['JJA_U_CANI_pvalue'] <= pvt)
JJA_W_CANI_sig = RA_reg_ds['JJA_W_CANI_slope'].where(RA_reg_ds['JJA_W_CANI_pvalue'] <= pvt)

SON_U_EANI_sig = RA_reg_ds['SON_U_EANI_slope'].where(RA_reg_ds['SON_U_EANI_pvalue'] <= pvt)
SON_W_EANI_sig = RA_reg_ds['SON_W_EANI_slope'].where(RA_reg_ds['SON_W_EANI_pvalue'] <= pvt)
SON_U_CANI_sig = RA_reg_ds['SON_U_CANI_slope'].where(RA_reg_ds['SON_U_CANI_pvalue'] <= pvt)
SON_W_CANI_sig = RA_reg_ds['SON_W_CANI_slope'].where(RA_reg_ds['SON_W_CANI_pvalue'] <= pvt)

# %%
plot_circulation(JJA_U_EANI_sig, JJA_W_EANI_sig, scale=500, index='EANI', season='JJA', source='ERA5')

# %%
plot_circulation(JJA_U_CANI_sig, JJA_W_CANI_sig, scale=500, index='CANI', season='JJA', source='ERA5')

# %%
plot_circulation(SON_U_EANI_sig, SON_W_EANI_sig, index='EANI', season='SON', source='ERA5')

# %%
plot_circulation(SON_U_CANI_sig, SON_W_CANI_sig, index='CANI', season='SON', source='ERA5')

# %% [markdown]
# # CESM2.1

# %%
ds = xr.open_zarr('/glade/work/acruz/CESM/wind_regression')
ds
# Out:
# <xarray.Dataset> Size: 33MB
# Dimensions:            (member: 100, level: 32, lon: 161)
# Coordinates:
#   * level              (level) float64 256B 3.643 7.595 14.36 ... 976.3 992.6
#   * lon                (lon) float64 1kB -180.0 -178.8 -177.5 ... 18.75 20.0
# Dimensions without coordinates: member
# Data variables: (12/16)
#     JJA_U_CANI_pvalue  (member, level, lon) float32 2MB dask.array<chunksize=(50, 16, 81), meta=np.ndarray>
#     JJA_U_CANI_slope   (member, level, lon) float32 2MB dask.array<chunksize=(15, 32, 161), meta=np.ndarray>
#     JJA_U_EANI_pvalue  (member, level, lon) float32 2MB dask.array<chunksize=(50, 16, 81), meta=np.ndarray>
#     JJA_U_EANI_slope   (member, level, lon) float32 2MB dask.array<chunksize=(15, 32, 161), meta=np.ndarray>
#     JJA_W_CANI_pvalue  (member, level, lon) float32 2MB dask.array<chunksize=(50, 16, 81), meta=np.ndarray>
#     JJA_W_CANI_slope   (member, level, lon) float32 2MB dask.array<chunksize=(15, 32, 161), meta=np.ndarray>
# ...

# %% [markdown]
# ## Mask before Ensemble Mean

# %%
# le: with large ensemble members separate
pvt = 0.05
JJA_U_EANI_sig_CESM_le = ds['JJA_U_EANI_slope'].where(ds['JJA_U_EANI_pvalue'] <= pvt)
JJA_W_EANI_sig_CESM_le = ds['JJA_W_EANI_slope'].where(ds['JJA_W_EANI_pvalue'] <= pvt)
JJA_U_CANI_sig_CESM_le = ds['JJA_U_CANI_slope'].where(ds['JJA_U_CANI_pvalue'] <= pvt)
JJA_W_CANI_sig_CESM_le = ds['JJA_W_CANI_slope'].where(ds['JJA_W_CANI_pvalue'] <= pvt)

SON_U_EANI_sig_CESM_le = ds['SON_U_EANI_slope'].where(ds['SON_U_EANI_pvalue'] <= pvt)
SON_W_EANI_sig_CESM_le = ds['SON_W_EANI_slope'].where(ds['SON_W_EANI_pvalue'] <= pvt)
SON_U_CANI_sig_CESM_le = ds['SON_U_CANI_slope'].where(ds['SON_U_CANI_pvalue'] <= pvt)
SON_W_CANI_sig_CESM_le = ds['SON_W_CANI_slope'].where(ds['SON_W_CANI_pvalue'] <= pvt)

# %%
JJA_U_EANI_sig_CESM_le.isel(member=1)
# Out:
# <xarray.DataArray 'JJA_U_EANI_slope' (level: 32, lon: 161)> Size: 21kB
# dask.array<getitem, shape=(32, 161), dtype=float32, chunksize=(16, 81), chunktype=numpy.ndarray>
# Coordinates:
#   * level    (level) float64 256B 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * lon      (lon) float64 1kB -180.0 -178.8 -177.5 -176.2 ... 17.5 18.75 20.0

# %% [markdown]
# ### selected members plot

# %%
def member_plot(U, W, select, s1='', s2=''):
        for m in selected_members:
            Uds = U.isel(member=m)
            Wds = W.isel(member=m)
            plot_circulation(Uds, Wds, season=s1, source=s2+f'member {m}')


selected_members = np.arange(0, 99, 5)
member_plot(JJA_U_EANI_sig_CESM_le, JJA_W_EANI_sig_CESM_le, selected_members, 'CESM')

# %% [markdown]
# ### Ensemble mean of masked data

# %%
JJA_U_EANI_sig_CESM_v2 = JJA_U_EANI_sig_CESM_le.mean(dim='member')
JJA_W_EANI_sig_CESM_v2 = JJA_W_EANI_sig_CESM_le.mean(dim='member')

JJA_U_CANI_sig_CESM_v2 = JJA_U_CANI_sig_CESM_le.mean(dim='member')
JJA_W_CANI_sig_CESM_v2 = JJA_W_CANI_sig_CESM_le.mean(dim='member')

SON_U_EANI_sig_CESM_v2 = SON_U_EANI_sig_CESM_le.mean(dim='member')
SON_W_EANI_sig_CESM_v2 = SON_W_EANI_sig_CESM_le.mean(dim='member')

SON_U_CANI_sig_CESM_v2 = SON_U_CANI_sig_CESM_le.mean(dim='member')
SON_W_CANI_sig_CESM_v2 = SON_W_CANI_sig_CESM_le.mean(dim='member')

# %%
plot_circulation(JJA_U_EANI_sig_CESM_v2,JJA_W_EANI_sig_CESM_v2, index='EANI', season='JJA', source='CESM_rev2')

# %%
plot_circulation(JJA_U_CANI_sig_CESM_v2, JJA_W_CANI_sig_CESM_v2, index='CANI', season='JJA', source='CESM_rev2')

# %%
plot_circulation(SON_U_EANI_sig_CESM_v2, SON_W_EANI_sig_CESM_v2, index='EANI', season='SON', source='CESM_rev2')

# %%
plot_circulation(SON_U_CANI_sig_CESM_v2, SON_W_CANI_sig_CESM_v2, index='CANI', season='SON', source='CESM_rev2')

# %% [markdown]
# ## Mask after Ensemble Mean
# Following other regression plots we will mask significance after calculating ensemble mean. Significance between members is so variant that the mean of all the significance fields is low in the whole globe providing little information.

# %%
ens_mean_ds = ds.mean(dim='member')
ens_mean_ds
# Out:
# <xarray.Dataset> Size: 331kB
# Dimensions:            (level: 32, lon: 161)
# Coordinates:
#   * level              (level) float64 256B 3.643 7.595 14.36 ... 976.3 992.6
#   * lon                (lon) float64 1kB -180.0 -178.8 -177.5 ... 18.75 20.0
# Data variables: (12/16)
#     JJA_U_CANI_pvalue  (level, lon) float32 21kB dask.array<chunksize=(16, 81), meta=np.ndarray>
#     JJA_U_CANI_slope   (level, lon) float32 21kB dask.array<chunksize=(32, 161), meta=np.ndarray>
#     JJA_U_EANI_pvalue  (level, lon) float32 21kB dask.array<chunksize=(16, 81), meta=np.ndarray>
#     JJA_U_EANI_slope   (level, lon) float32 21kB dask.array<chunksize=(32, 161), meta=np.ndarray>
#     JJA_W_CANI_pvalue  (level, lon) float32 21kB dask.array<chunksize=(16, 81), meta=np.ndarray>
#     JJA_W_CANI_slope   (level, lon) float32 21kB dask.array<chunksize=(32, 161), meta=np.ndarray>
#     ...                 ...
# ...

# %%
# mask by pvalue threshold
pvt = 0.05

JJA_U_EANI_sig_CESM = ens_mean_ds['JJA_U_EANI_slope'].where(ens_mean_ds['JJA_U_EANI_pvalue'] <= pvt)
JJA_W_EANI_sig_CESM = ens_mean_ds['JJA_W_EANI_slope'].where(ens_mean_ds['JJA_W_EANI_pvalue'] <= pvt)
JJA_U_CANI_sig_CESM = ens_mean_ds['JJA_U_CANI_slope'].where(ens_mean_ds['JJA_U_CANI_pvalue'] <= pvt)
JJA_W_CANI_sig_CESM = ens_mean_ds['JJA_W_CANI_slope'].where(ens_mean_ds['JJA_W_CANI_pvalue'] <= pvt)

SON_U_EANI_sig_CESM = ens_mean_ds['SON_U_EANI_slope'].where(ens_mean_ds['SON_U_EANI_pvalue'] <= pvt)
SON_W_EANI_sig_CESM = ens_mean_ds['SON_W_EANI_slope'].where(ens_mean_ds['SON_W_EANI_pvalue'] <= pvt)
SON_U_CANI_sig_CESM = ens_mean_ds['SON_U_CANI_slope'].where(ens_mean_ds['SON_U_CANI_pvalue'] <= pvt)
SON_W_CANI_sig_CESM = ens_mean_ds['SON_W_CANI_slope'].where(ens_mean_ds['SON_W_CANI_pvalue'] <= pvt)

# %%
plot_circulation(JJA_U_EANI_sig_CESM, JJA_W_EANI_sig_CESM, index='EANI', season='JJA', source='CESM')

# %%
plot_circulation(JJA_U_CANI_sig_CESM, JJA_W_CANI_sig_CESM, index='CANI', season='JJA', source='CESM')
# Out:
# /glade/u/home/acruz/.conda/envs/analysis_11_20_2025/lib/python3.11/site-packages/matplotlib/quiver.py:676: RuntimeWarning: Mean of empty slice.
#   amean = a[~self.Umask].mean()
# /glade/u/home/acruz/.conda/envs/analysis_11_20_2025/lib/python3.11/site-packages/numpy/_core/_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_circulation(SON_U_EANI_sig_CESM, SON_W_EANI_sig_CESM, index='EANI', season='SON', source='CESM')

# %%
plot_circulation(SON_U_CANI_sig_CESM, SON_W_CANI_sig_CESM, index='CANI', season='SON', source='CESM')

# %% [markdown]
# # E3SMv2

# %%
E3SM_ds = xr.open_zarr('/glade/work/acruz/E3SMv2LE/wind_regression')
E3SM_ds
# Out:
# <xarray.Dataset> Size: 16MB
# Dimensions:            (member: 21, level: 72, lon: 161)
# Coordinates:
#   * level              (level) float64 576B 0.1238 0.1828 0.2699 ... 993.8 998.5
#   * lon                (lon) float64 1kB -180.0 -178.8 -177.5 ... 18.75 20.0
# Dimensions without coordinates: member
# Data variables: (12/16)
#     JJA_U_CANI_pvalue  (member, level, lon) float32 974kB dask.array<chunksize=(11, 36, 161), meta=np.ndarray>
#     JJA_U_CANI_slope   (member, level, lon) float32 974kB dask.array<chunksize=(21, 72, 161), meta=np.ndarray>
#     JJA_U_EANI_pvalue  (member, level, lon) float32 974kB dask.array<chunksize=(11, 36, 161), meta=np.ndarray>
#     JJA_U_EANI_slope   (member, level, lon) float32 974kB dask.array<chunksize=(21, 72, 161), meta=np.ndarray>
#     JJA_W_CANI_pvalue  (member, level, lon) float32 974kB dask.array<chunksize=(11, 36, 161), meta=np.ndarray>
# ...

# %% [markdown]
# ## Masking before ensemble mean

# %%
# le: with large ensemble members separate
pvt = 0.05
JJA_U_EANI_sig_E3SM_le = E3SM_ds['JJA_U_EANI_slope'].where(E3SM_ds['JJA_U_EANI_pvalue'] <= pvt)
JJA_W_EANI_sig_E3SM_le = E3SM_ds['JJA_W_EANI_slope'].where(E3SM_ds['JJA_W_EANI_pvalue'] <= pvt)
JJA_U_CANI_sig_E3SM_le = E3SM_ds['JJA_U_CANI_slope'].where(E3SM_ds['JJA_U_CANI_pvalue'] <= pvt)
JJA_W_CANI_sig_E3SM_le = E3SM_ds['JJA_W_CANI_slope'].where(E3SM_ds['JJA_W_CANI_pvalue'] <= pvt)

SON_U_EANI_sig_E3SM_le = E3SM_ds['SON_U_EANI_slope'].where(E3SM_ds['SON_U_EANI_pvalue'] <= pvt)
SON_W_EANI_sig_E3SM_le = E3SM_ds['SON_W_EANI_slope'].where(E3SM_ds['SON_W_EANI_pvalue'] <= pvt)
SON_U_CANI_sig_E3SM_le = E3SM_ds['SON_U_CANI_slope'].where(E3SM_ds['SON_U_CANI_pvalue'] <= pvt)
SON_W_CANI_sig_E3SM_le = E3SM_ds['SON_W_CANI_slope'].where(E3SM_ds['SON_W_CANI_pvalue'] <= pvt)

# %%
JJA_U_EANI_sig_E3SM_v2 = JJA_U_EANI_sig_E3SM_le.mean(dim='member')
JJA_W_EANI_sig_E3SM_v2 = JJA_W_EANI_sig_E3SM_le.mean(dim='member')

JJA_U_CANI_sig_E3SM_v2 = JJA_U_CANI_sig_E3SM_le.mean(dim='member')
JJA_W_CANI_sig_E3SM_v2 = JJA_W_CANI_sig_E3SM_le.mean(dim='member')

SON_U_EANI_sig_E3SM_v2 = SON_U_EANI_sig_E3SM_le.mean(dim='member')
SON_W_EANI_sig_E3SM_v2 = SON_W_EANI_sig_E3SM_le.mean(dim='member')

SON_U_CANI_sig_E3SM_v2 = SON_U_CANI_sig_E3SM_le.mean(dim='member')
SON_W_CANI_sig_E3SM_v2 = SON_W_CANI_sig_E3SM_le.mean(dim='member')

# %%
plot_circulation(JJA_U_EANI_sig_E3SM_v2, JJA_W_EANI_sig_E3SM_v2, index='EANI', season='JJA', source='E3SM_rev2')

# %%
plot_circulation(JJA_U_CANI_sig_E3SM_v2, JJA_W_CANI_sig_E3SM_v2, index='CANI', season='JJA', source='E3SM_rev2')

# %%
plot_circulation(SON_U_EANI_sig_E3SM_v2, SON_W_EANI_sig_E3SM_v2, index='EANI', season='SON', source='E3SM_rev2')

# %%
plot_circulation(SON_U_CANI_sig_E3SM_v2, SON_W_CANI_sig_E3SM_v2, index='CANI', season='SON', source='E3SM_rev2')

# %% [markdown]
# ## Masking after ensemble mean

# %%
ens_mean_E3SM_ds = E3SM_ds.mean(dim='member')
ens_mean_E3SM_ds
# Out:
# <xarray.Dataset> Size: 744kB
# Dimensions:            (level: 72, lon: 161)
# Coordinates:
#   * level              (level) float64 576B 0.1238 0.1828 0.2699 ... 993.8 998.5
#   * lon                (lon) float64 1kB -180.0 -178.8 -177.5 ... 18.75 20.0
# Data variables: (12/16)
#     JJA_U_CANI_pvalue  (level, lon) float32 46kB dask.array<chunksize=(36, 161), meta=np.ndarray>
#     JJA_U_CANI_slope   (level, lon) float32 46kB dask.array<chunksize=(72, 161), meta=np.ndarray>
#     JJA_U_EANI_pvalue  (level, lon) float32 46kB dask.array<chunksize=(36, 161), meta=np.ndarray>
#     JJA_U_EANI_slope   (level, lon) float32 46kB dask.array<chunksize=(72, 161), meta=np.ndarray>
#     JJA_W_CANI_pvalue  (level, lon) float32 46kB dask.array<chunksize=(36, 161), meta=np.ndarray>
#     JJA_W_CANI_slope   (level, lon) float32 46kB dask.array<chunksize=(72, 161), meta=np.ndarray>
#     ...                 ...
# ...

# %%
# mask by pvalue threshold
pvt = 0.05

JJA_U_EANI_sig_E3SM = ens_mean_E3SM_ds['JJA_U_EANI_slope'].where(ens_mean_E3SM_ds['JJA_U_EANI_pvalue'] <= pvt)
JJA_W_EANI_sig_E3SM = ens_mean_E3SM_ds['JJA_W_EANI_slope'].where(ens_mean_E3SM_ds['JJA_W_EANI_pvalue'] <= pvt)
JJA_U_CANI_sig_E3SM = ens_mean_E3SM_ds['JJA_U_CANI_slope'].where(ens_mean_E3SM_ds['JJA_U_CANI_pvalue'] <= pvt)
JJA_W_CANI_sig_E3SM = ens_mean_E3SM_ds['JJA_W_CANI_slope'].where(ens_mean_E3SM_ds['JJA_W_CANI_pvalue'] <= pvt)

SON_U_EANI_sig_E3SM = ens_mean_E3SM_ds['SON_U_EANI_slope'].where(ens_mean_E3SM_ds['SON_U_EANI_pvalue'] <= pvt)
SON_W_EANI_sig_E3SM = ens_mean_E3SM_ds['SON_W_EANI_slope'].where(ens_mean_E3SM_ds['SON_W_EANI_pvalue'] <= pvt)
SON_U_CANI_sig_E3SM = ens_mean_E3SM_ds['SON_U_CANI_slope'].where(ens_mean_E3SM_ds['SON_U_CANI_pvalue'] <= pvt)
SON_W_CANI_sig_E3SM = ens_mean_E3SM_ds['SON_W_CANI_slope'].where(ens_mean_E3SM_ds['SON_W_CANI_pvalue'] <= pvt)

# %%
plot_circulation(JJA_U_EANI_sig_E3SM, JJA_W_EANI_sig_E3SM, index='EANI', season='JJA', source='E3SM')
# Out:
# /glade/u/home/acruz/.conda/envs/analysis_11_20_2025/lib/python3.11/site-packages/matplotlib/quiver.py:676: RuntimeWarning: Mean of empty slice.
#   amean = a[~self.Umask].mean()
# /glade/u/home/acruz/.conda/envs/analysis_11_20_2025/lib/python3.11/site-packages/numpy/_core/_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_circulation(JJA_U_CANI_sig_E3SM, JJA_W_CANI_sig_E3SM, index='CANI', season='JJA', source='E3SM')

# %%
plot_circulation(SON_U_EANI_sig_E3SM, SON_W_EANI_sig_E3SM, index='EANI', season='SON', source='E3SM')
# Out:
# /glade/u/home/acruz/.conda/envs/analysis_11_20_2025/lib/python3.11/site-packages/matplotlib/quiver.py:676: RuntimeWarning: Mean of empty slice.
#   amean = a[~self.Umask].mean()
# /glade/u/home/acruz/.conda/envs/analysis_11_20_2025/lib/python3.11/site-packages/numpy/_core/_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_circulation(SON_U_CANI_sig_E3SM, SON_W_CANI_sig_E3SM, index='CANI', season='SON', source='E3SM')
